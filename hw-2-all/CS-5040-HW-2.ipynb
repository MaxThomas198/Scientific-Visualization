# %%
from IPython.display import Image

# %% [markdown]
# 1A.) Paraview assigned Polygonal Mesh data type when I first loaded the data. You can find it in information tab of Paraview on the bottom left of the interface. One advantage of this data type is it does a great job at spatial representation, especially of an uneven surface. Using a different data type like uniform or non-uniform Rectilinear would prevent you from getting a good view while using surface representation.

# %%
Image("SurfaceHI.png")

# %%
Image("height.png")

# %%
Image("peaks.png")

# %% [markdown]
# 2A.) The data type assigned to headsq intially is Uniform Rectilinear Grid(Image).

# %%
Image("skullandhistogram.png")

# %%
Image("contours.png")

# %% [markdown]
# 2C.) I chose the isovlaues based on data from the histogram. For skin I assigned the value of 1000, for the skull I assigned 2000, and for the teeth I assigned 3000. Each gave distinct colors and by varing the opacity the various isosurfaces can be seen all at once.

# %%
Image("cross.png")

# %%
Image("streamlines.png")

# %%
Image("streamandcones.png")

# %%
Image("arrows.png")

# %%
Image("Molecules.png")

# %%
Image("ctscan.png")
